# %% [markdown]
# # Polynomial Regression Notebook
#
# #### Denzell Ford, fdenzell@gmail.com

# %% [markdown]
# Import `pandas` and `numpy` for data structures, and `seaborn` and `matplotlib` for viz

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns; sns.set()
# %matplotlib inline

# %% [markdown]
# Read in the data with `pandas`

# %%
data = pd.read_csv(r'well_data.csv')

# %% [markdown]
# Let's create a subsample of the data so things run a bit faster using `pandas` `.sample()` method

# %%
x = data.AHTCO60.values
y = data.DT.values
plt.scatter(x, y)
plt.xlabel('Medium Conductivity (AHTCO60)')
plt.ylabel('Sonic Velocity (DT)')
# Out:
# Text(0, 0.5, 'Sonic Velocity (DT)')

# %%
x = x.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
train_x, test_x, train_y, test_y = train_test_split(x, y, random_state=30, test_size=0.70)

# %% [markdown]
# We are going to do a support vector regression. To do this we need to import `SVR` from `sklearn`. We are going to use the polynomial kernel of degree 4 with gamma set to scale. As with all the `sklearn` classes, we need to first `fit` the regressor before we can make predictions with it

# %%
from sklearn.svm import SVR

# %%
svr = SVR(kernel='rbf', degree=4, gamma='scale')
svr.fit(train_x, train_y)
# Out:
# SVR(degree=4)

# %% [markdown]
# Now let's wrap our predictions into our plot and plot up our dataset along with the regression

# %%
xp = np.linspace(50,150,20)

fig, ax = plt.subplots(1, 1, figsize=(5,5))

ax.scatter(test_x, test_y, alpha=0.1, color='r', label='test')
ax.scatter(train_x, train_y, alpha=0.5, color='g', label='train')
plt.legend()
ax.plot(xp, svr.predict(xp.reshape(-1,1)))

# %% [markdown]
# we can also get the R-squared value just like in linear regression

# %%
svr.score(test_x, test_y)
# Out:
# 0.7504448067024811
